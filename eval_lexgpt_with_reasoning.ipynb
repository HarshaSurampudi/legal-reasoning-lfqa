# %%
# !pip install pandas -q
# !pip install rouge -q

# %%
import pandas as pd

# %%
df = pd.read_csv('lex_test_generated_reason.csv')

df.head()
# Out:
#                                              Context  \
# 0  and Statistical Manual of Mental Disorders 446...
# 1  one of his trial counsel as a witness, so the ...
# 2  Some of Cruikshank’s objections on appeal appe...
# 3  noting that the additional materials provided ...
# 4  The State is within the powers reserved to it ...
#
#                                             Question  \
# 0  Can the defendants force Dr. Nadel to provide ...
# 1  Did the Appellee's trial counsel have knowledg...
# 2  Can Cruikshank's objections on the trial court...
# 3  Can the motion to strike filed by PFM be consi...
# 4  Can the State refuse to enter into agreements ...
#
#                                      Legal Reasoning  \
# 0  The issue at hand pertains to the compulsion o...
# 1  The question at hand pertains to the knowledge...
# 2  The issue at hand pertains to the admissibilit...
# 3  The question pertains to the categorization of...
# 4  The question revolves around the State's power...
#
#                                               Answer  \
# 0  No, according to the Graham v. Gielchinsky cas...
# 1  It is uncertain whether the Appellee's trial c...
# 2  No, Cruikshank's objections on the trial court...
# 3  Yes, the motion to strike filed by PFM can be ...
# 4  Yes, the State has the power to refuse to ente...
#
#                                               Prompt  \
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 2  Context:\nSome of Cruikshank’s objections on a...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...
#
#                                       Generated Text
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 2  Context:\nSome of Cruikshank’s objections on a...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...

# %%
import re

# Function to extract answer using regular expression.
def extract_answer(text):
    match = re.search(r'Answer:\n(.*?)(?:\n|$)', text)
    if match:
        return match.group(1)
    return None

# Apply the function to the 'Generated Text' column.
df['Generated Answer'] = df['Generated Text'].apply(extract_answer)

df.head()
# Out:
#                                              Context  \
# 0  and Statistical Manual of Mental Disorders 446...
# 1  one of his trial counsel as a witness, so the ...
# 2  Some of Cruikshank’s objections on appeal appe...
# 3  noting that the additional materials provided ...
# 4  The State is within the powers reserved to it ...
#
#                                             Question  \
# 0  Can the defendants force Dr. Nadel to provide ...
# 1  Did the Appellee's trial counsel have knowledg...
# 2  Can Cruikshank's objections on the trial court...
# 3  Can the motion to strike filed by PFM be consi...
# 4  Can the State refuse to enter into agreements ...
#
#                                      Legal Reasoning  \
# 0  The issue at hand pertains to the compulsion o...
# 1  The question at hand pertains to the knowledge...
# 2  The issue at hand pertains to the admissibilit...
# 3  The question pertains to the categorization of...
# 4  The question revolves around the State's power...
#
#                                               Answer  \
# 0  No, according to the Graham v. Gielchinsky cas...
# 1  It is uncertain whether the Appellee's trial c...
# 2  No, Cruikshank's objections on the trial court...
# 3  Yes, the motion to strike filed by PFM can be ...
# 4  Yes, the State has the power to refuse to ente...
#
#                                               Prompt  \
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 2  Context:\nSome of Cruikshank’s objections on a...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...
#
#                                       Generated Text  \
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 2  Context:\nSome of Cruikshank’s objections on a...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...
#
#                                     Generated Answer
# 0  No. As explained in part III.G, expert testimo...
# 1  Based on the record before us, it is impossibl...
# 2                                               None
# 3  Whether PFM may move for summary judgment coul...
# 4  Yes, it can refuse to enter into agreements un...

# %%
#drop na

df.dropna(inplace=True)

df
# Out:
#                                                 Context  \
# 0     and Statistical Manual of Mental Disorders 446...
# 1     one of his trial counsel as a witness, so the ...
# 3     noting that the additional materials provided ...
# 4     The State is within the powers reserved to it ...
# 6     many seemingly anomalous situations. For examp...
# ...                                                 ...
# 1488  of the average layper son.” Dominguez, 183 Cal...
# 1489  to use the private roads in St. Lucie West wer...
# 1494  criminal laws.” Spaziano v. Florida, 468 U.S. ...
# 1495  F.Supp.3d 700, 703, No. 3:14CV200 (JMM), 2014 ...
# 1496  First, the proposed Second Amended Complaint m...
#
#                                                Question  \
# 0     Can the defendants force Dr. Nadel to provide ...
# 1     Did the Appellee's trial counsel have knowledg...
# 3     Can the motion to strike filed by PFM be consi...
# 4     Can the State refuse to enter into agreements ...
# 6     When would mandatory withdrawal be required in...
# ...                                                 ...
# 1488  Is limiting language considered plain and clea...
# 1489  Does White's prohibition of Centel's access to...
# 1494  Can the sentence imposed on Williams be consid...
# 1495  Can an entity be held liable for unsolicited c...
# 1496  Is there a causal relationship between Plainti...
#
#                                         Legal Reasoning  \
# 0     The issue at hand pertains to the compulsion o...
# 1     The question at hand pertains to the knowledge...
# 3     The question pertains to the categorization of...
# 4     The question revolves around the State's power...
# 6     The question pertains to the circumstances in ...
# ...                                                 ...
# 1488  The question focuses on the interpretation of ...
# 1489  The question concerns the violation of the Cab...
# 1494  The question pertains to the constitutionality...
# 1495  The question pertains to the liability of an e...
# 1496  The question pertains to the causal relationsh...
#
#                                                  Answer  \
# 0     No, according to the Graham v. Gielchinsky cas...
# 1     It is uncertain whether the Appellee's trial c...
# 3     Yes, the motion to strike filed by PFM can be ...
# 4     Yes, the State has the power to refuse to ente...
# 6     Mandatory withdrawal is required in a court ca...
# ...                                                 ...
# 1488  No, limiting language in insurance contracts i...
# 1489  Yes, White's prohibition of Centel's access to...
# 1494  No, the sentence imposed on Williams is not un...
# 1495  Yes, an entity can be held liable for unsolici...
# 1496  No, there is no established causal relationshi...
#
#                                                  Prompt  \
# 0     Context:\nand Statistical Manual of Mental Dis...
# 1     Context:\none of his trial counsel as a witnes...
# 3     Context:\nnoting that the additional materials...
# 4     Context:\nThe State is within the powers reser...
# 6     Context:\nmany seemingly anomalous situations....
# ...                                                 ...
# 1488  Context:\nof the average layper son.” Domingue...
# 1489  Context:\nto use the private roads in St. Luci...
# 1494  Context:\ncriminal laws.” Spaziano v. Florida,...
# 1495  Context:\nF.Supp.3d 700, 703, No. 3:14CV200 (J...
# 1496  Context:\nFirst, the proposed Second Amended C...
#
#                                          Generated Text  \
# 0     Context:\nand Statistical Manual of Mental Dis...
# 1     Context:\none of his trial counsel as a witnes...
# 3     Context:\nnoting that the additional materials...
# 4     Context:\nThe State is within the powers reser...
# 6     Context:\nmany seemingly anomalous situations....
# ...                                                 ...
# 1488  Context:\nof the average layper son.” Domingue...
# 1489  Context:\nto use the private roads in St. Luci...
# 1494  Context:\ncriminal laws.” Spaziano v. Florida,...
# 1495  Context:\nF.Supp.3d 700, 703, No. 3:14CV200 (J...
# 1496  Context:\nFirst, the proposed Second Amended C...
#
#                                        Generated Answer
# 0     No. As explained in part III.G, expert testimo...
# 1     Based on the record before us, it is impossibl...
# 3     Whether PFM may move for summary judgment coul...
# 4     Yes, it can refuse to enter into agreements un...
# 6     Mandatory withdrawal of the bankruptcy case wo...
# ...                                                 ...
# 1488  The question addresses the understanding of th...
# 1489  None of the Cable Act terms prohibit a cable c...
# 1494  No, this case does not involve the question of...
# 1495  Both courts held or intimated that an entity c...
# 1496  Yes, if the relevant conduct began after Plain...
#
# [919 rows x 7 columns]

# %%
#remove rows where generated answer is empty

df = df[df['Generated Answer'] != '']

df
# Out:
#                                                 Context  \
# 0     and Statistical Manual of Mental Disorders 446...
# 1     one of his trial counsel as a witness, so the ...
# 3     noting that the additional materials provided ...
# 4     The State is within the powers reserved to it ...
# 6     many seemingly anomalous situations. For examp...
# ...                                                 ...
# 1488  of the average layper son.” Dominguez, 183 Cal...
# 1489  to use the private roads in St. Lucie West wer...
# 1494  criminal laws.” Spaziano v. Florida, 468 U.S. ...
# 1495  F.Supp.3d 700, 703, No. 3:14CV200 (JMM), 2014 ...
# 1496  First, the proposed Second Amended Complaint m...
#
#                                                Question  \
# 0     Can the defendants force Dr. Nadel to provide ...
# 1     Did the Appellee's trial counsel have knowledg...
# 3     Can the motion to strike filed by PFM be consi...
# 4     Can the State refuse to enter into agreements ...
# 6     When would mandatory withdrawal be required in...
# ...                                                 ...
# 1488  Is limiting language considered plain and clea...
# 1489  Does White's prohibition of Centel's access to...
# 1494  Can the sentence imposed on Williams be consid...
# 1495  Can an entity be held liable for unsolicited c...
# 1496  Is there a causal relationship between Plainti...
#
#                                         Legal Reasoning  \
# 0     The issue at hand pertains to the compulsion o...
# 1     The question at hand pertains to the knowledge...
# 3     The question pertains to the categorization of...
# 4     The question revolves around the State's power...
# 6     The question pertains to the circumstances in ...
# ...                                                 ...
# 1488  The question focuses on the interpretation of ...
# 1489  The question concerns the violation of the Cab...
# 1494  The question pertains to the constitutionality...
# 1495  The question pertains to the liability of an e...
# 1496  The question pertains to the causal relationsh...
#
#                                                  Answer  \
# 0     No, according to the Graham v. Gielchinsky cas...
# 1     It is uncertain whether the Appellee's trial c...
# 3     Yes, the motion to strike filed by PFM can be ...
# 4     Yes, the State has the power to refuse to ente...
# 6     Mandatory withdrawal is required in a court ca...
# ...                                                 ...
# 1488  No, limiting language in insurance contracts i...
# 1489  Yes, White's prohibition of Centel's access to...
# 1494  No, the sentence imposed on Williams is not un...
# 1495  Yes, an entity can be held liable for unsolici...
# 1496  No, there is no established causal relationshi...
#
#                                                  Prompt  \
# 0     Context:\nand Statistical Manual of Mental Dis...
# 1     Context:\none of his trial counsel as a witnes...
# 3     Context:\nnoting that the additional materials...
# 4     Context:\nThe State is within the powers reser...
# 6     Context:\nmany seemingly anomalous situations....
# ...                                                 ...
# 1488  Context:\nof the average layper son.” Domingue...
# 1489  Context:\nto use the private roads in St. Luci...
# 1494  Context:\ncriminal laws.” Spaziano v. Florida,...
# 1495  Context:\nF.Supp.3d 700, 703, No. 3:14CV200 (J...
# 1496  Context:\nFirst, the proposed Second Amended C...
#
#                                          Generated Text  \
# 0     Context:\nand Statistical Manual of Mental Dis...
# 1     Context:\none of his trial counsel as a witnes...
# 3     Context:\nnoting that the additional materials...
# 4     Context:\nThe State is within the powers reser...
# 6     Context:\nmany seemingly anomalous situations....
# ...                                                 ...
# 1488  Context:\nof the average layper son.” Domingue...
# 1489  Context:\nto use the private roads in St. Luci...
# 1494  Context:\ncriminal laws.” Spaziano v. Florida,...
# 1495  Context:\nF.Supp.3d 700, 703, No. 3:14CV200 (J...
# 1496  Context:\nFirst, the proposed Second Amended C...
#
#                                        Generated Answer
# 0     No. As explained in part III.G, expert testimo...
# 1     Based on the record before us, it is impossibl...
# 3     Whether PFM may move for summary judgment coul...
# 4     Yes, it can refuse to enter into agreements un...
# 6     Mandatory withdrawal of the bankruptcy case wo...
# ...                                                 ...
# 1488  The question addresses the understanding of th...
# 1489  None of the Cable Act terms prohibit a cable c...
# 1494  No, this case does not involve the question of...
# 1495  Both courts held or intimated that an entity c...
# 1496  Yes, if the relevant conduct began after Plain...
#
# [917 rows x 7 columns]

# %%
from rouge import Rouge

# Initialize the Rouge object
rouge = Rouge()

# Function to compute ROUGE scores between 'Answer' and 'Actual Answer' columns
def compute_rouge_scores(row):
    scores = rouge.get_scores(row['Generated Answer'], row['Answer'])
    return scores[0]

# Apply the function to each row of the dataframe
df['ROUGE Scores'] = df.apply(compute_rouge_scores, axis=1)

# Display the dataframe with the ROUGE scores
print(df['ROUGE Scores'])
# Out:
# 0       {'rouge-1': {'r': 0.3448275862068966, 'p': 0.2...
# 1       {'rouge-1': {'r': 0.4, 'p': 0.2857142857142857...
# 3       {'rouge-1': {'r': 0.5925925925925926, 'p': 0.3...
# 4       {'rouge-1': {'r': 0.325, 'p': 0.30232558139534...
# 6       {'rouge-1': {'r': 0.24528301886792453, 'p': 0....
#                               ...
# 1488    {'rouge-1': {'r': 0.030303030303030304, 'p': 0...
# 1489    {'rouge-1': {'r': 0.34615384615384615, 'p': 0....
# 1494    {'rouge-1': {'r': 0.5769230769230769, 'p': 0.2...
# 1495    {'rouge-1': {'r': 0.5531914893617021, 'p': 0.3...
# 1496    {'rouge-1': {'r': 0.2, 'p': 0.4090909090909091...
# Name: ROUGE Scores, Length: 917, dtype: object
# /tmp/ipykernel_33289/1001850967.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ROUGE Scores'] = df.apply(compute_rouge_scores, axis=1)

# %%
total_rows = len(df)
total_rouge_1_f1 = 0
total_rouge_2_f1 = 0
total_rouge_l_f1 = 0
total_rouge_1_precision = 0
total_rouge_2_precision = 0
total_rouge_l_precision = 0
total_rouge_1_recall = 0
total_rouge_2_recall = 0
total_rouge_l_recall = 0

for row in df['ROUGE Scores']:
    total_rouge_1_f1 += row['rouge-1']['f']
    total_rouge_2_f1 += row['rouge-2']['f']
    total_rouge_l_f1 += row['rouge-l']['f']
    total_rouge_1_precision += row['rouge-1']['p']
    total_rouge_2_precision += row['rouge-2']['p']
    total_rouge_l_precision += row['rouge-l']['p']
    total_rouge_1_recall += row['rouge-1']['r']
    total_rouge_2_recall += row['rouge-2']['r']
    total_rouge_l_recall += row['rouge-l']['r']

average_rouge_1_f1 = total_rouge_1_f1 / total_rows
average_rouge_2_f1 = total_rouge_2_f1 / total_rows
average_rouge_l_f1 = total_rouge_l_f1 / total_rows
average_rouge_1_precision = total_rouge_1_precision / total_rows
average_rouge_2_precision = total_rouge_2_precision / total_rows
average_rouge_l_precision = total_rouge_l_precision / total_rows
average_rouge_1_recall = total_rouge_1_recall / total_rows
average_rouge_2_recall = total_rouge_2_recall / total_rows
average_rouge_l_recall = total_rouge_l_recall / total_rows

print("Average ROUGE-1 F1 Score:", average_rouge_1_f1)
print("Average ROUGE-2 F1 Score:", average_rouge_2_f1)
print("Average ROUGE-L F1 Score:", average_rouge_l_f1)
print("Average ROUGE-1 Precision:", average_rouge_1_precision)
print("Average ROUGE-2 Precision:", average_rouge_2_precision)
print("Average ROUGE-L Precision:", average_rouge_l_precision)
print("Average ROUGE-1 Recall:", average_rouge_1_recall)
print("Average ROUGE-2 Recall:", average_rouge_2_recall)
print("Average ROUGE-L Recall:", average_rouge_l_recall)
# Out:
# Average ROUGE-1 F1 Score: 0.30537926600018317
# Average ROUGE-2 F1 Score: 0.14859138749526882
# Average ROUGE-L F1 Score: 0.27029372735864937
# Average ROUGE-1 Precision: 0.3422815352913371
# Average ROUGE-2 Precision: 0.1678941451809408
# Average ROUGE-L Precision: 0.3051368713173905
# Average ROUGE-1 Recall: 0.32196714471306986
# Average ROUGE-2 Recall: 0.1643758585934575
# Average ROUGE-L Recall: 0.28424247714815887

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load the pre-trained SentenceTransformer model
model = SentenceTransformer('Stern5497/sbert-legal-xlm-roberta-base')

# Calculate the semantic similarity between 'Answer' and 'Actual Answer' columns
similarity_scores = []

for i, row in df.iterrows():
    answer_embedding = model.encode([row['Generated Answer']])
    actual_answer_embedding = model.encode([row['Answer']])
    similarity = cosine_similarity(answer_embedding, actual_answer_embedding)
    similarity_scores.append(similarity[0][0])

# Add the similarity scores to the dataframe
df['Semantic Similarity'] = similarity_scores
# Out:
# 2023-08-23 13:23:02.399946: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 13:23:03.190027: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /tmp/ipykernel_33289/3086920933.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Semantic Similarity'] = similarity_scores

# %%
df['Semantic Similarity'].mean()
# Out:
# 0.8081372

# %%
import re

# Function to extract answer using regular expression.
def extract_reasoning(text):
    match = re.search(r'Reasoning:\n(.*?)(?:\n|$)', text)
    if match:
        return match.group(1)
    return None

# Apply the function to the 'Generated Text' column.
df['Generated Reasoning'] = df['Generated Text'].apply(extract_reasoning)

df.head()
# Out:
# /tmp/ipykernel_33289/913379706.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Generated Reasoning'] = df['Generated Text'].apply(extract_reasoning)
#                                              Context  \
# 0  and Statistical Manual of Mental Disorders 446...
# 1  one of his trial counsel as a witness, so the ...
# 3  noting that the additional materials provided ...
# 4  The State is within the powers reserved to it ...
# 6  many seemingly anomalous situations. For examp...
#
#                                             Question  \
# 0  Can the defendants force Dr. Nadel to provide ...
# 1  Did the Appellee's trial counsel have knowledg...
# 3  Can the motion to strike filed by PFM be consi...
# 4  Can the State refuse to enter into agreements ...
# 6  When would mandatory withdrawal be required in...
#
#                                      Legal Reasoning  \
# 0  The issue at hand pertains to the compulsion o...
# 1  The question at hand pertains to the knowledge...
# 3  The question pertains to the categorization of...
# 4  The question revolves around the State's power...
# 6  The question pertains to the circumstances in ...
#
#                                               Answer  \
# 0  No, according to the Graham v. Gielchinsky cas...
# 1  It is uncertain whether the Appellee's trial c...
# 3  Yes, the motion to strike filed by PFM can be ...
# 4  Yes, the State has the power to refuse to ente...
# 6  Mandatory withdrawal is required in a court ca...
#
#                                               Prompt  \
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...
# 6  Context:\nmany seemingly anomalous situations....
#
#                                       Generated Text  \
# 0  Context:\nand Statistical Manual of Mental Dis...
# 1  Context:\none of his trial counsel as a witnes...
# 3  Context:\nnoting that the additional materials...
# 4  Context:\nThe State is within the powers reser...
# 6  Context:\nmany seemingly anomalous situations....
#
#                                     Generated Answer  \
# 0  No. As explained in part III.G, expert testimo...
# 1  Based on the record before us, it is impossibl...
# 3  Whether PFM may move for summary judgment coul...
# 4  Yes, it can refuse to enter into agreements un...
# 6  Mandatory withdrawal of the bankruptcy case wo...
#
#                                         ROUGE Scores  Semantic Similarity  \
# 0  {'rouge-1': {'r': 0.3448275862068966, 'p': 0.2...             0.902726
# 1  {'rouge-1': {'r': 0.4, 'p': 0.2857142857142857...             0.884608
# 3  {'rouge-1': {'r': 0.5925925925925926, 'p': 0.3...             0.864483
# 4  {'rouge-1': {'r': 0.325, 'p': 0.30232558139534...             0.799358
# 6  {'rouge-1': {'r': 0.24528301886792453, 'p': 0....             0.700356
#
#                                  Generated Reasoning
# 0  In summation, I cannot reconcile the court's o...
# 1  The question involves the legal adequacy of th...
# 3  Rule 13(a)(1) provides that a motion to strike...
# 4  Lutheran’s law on the subject is simple and cl...
# 6  The question involves a dispute between a bank...

# %%
from rouge import Rouge

# Initialize the Rouge object
rouge = Rouge()

# Function to compute ROUGE scores between 'Answer' and 'Actual Answer' columns
def compute_reasoning_rouge_scores(row):
    scores = rouge.get_scores(row['Generated Reasoning'], row['Legal Reasoning'])
    return scores[0]

# Apply the function to each row of the dataframe
df['Reasoning ROUGE Scores'] = df.apply(compute_reasoning_rouge_scores, axis=1)

# Display the dataframe with the ROUGE scores
print(df['Reasoning ROUGE Scores'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb Cell 13 line 1
#       <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     return scores[0]
#      <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> # Apply the function to each row of the dataframe
# ---> <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> df['Reasoning ROUGE Scores'] = df.apply(compute_reasoning_rouge_scores, axis=1)
#      <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> # Display the dataframe with the ROUGE scores
#      <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> print(df['Reasoning ROUGE Scores'])
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# /home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb Cell 13 line 8
#       <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> def compute_reasoning_rouge_scores(row):
# ----> <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     scores = rouge.get_scores(row['Generated Reasoning'], row['Legal Reasoning'])
#       <a href='vscode-notebook-cell:/home/harsha/msc_proj/legal-reasoning-lfqa/eval_lexgpt_with_reasoning.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     return scores[0]
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/rouge/rouge.py:107, in Rouge.get_scores(self, hyps, refs, avg, ignore_empty)
#     104 assert(len(hyps) == len(refs))
#     106 if not avg:
# --> 107     return self._get_scores(hyps, refs)
#     108 return self._get_avg_scores(hyps, refs)
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/rouge/rouge.py:120, in Rouge._get_scores(self, hyps, refs)
#     118 for m in self.metrics:
#     119     fn = Rouge.AVAILABLE_METRICS[m]
# --> 120     sc = fn(
#     121         hyp,
#     122         ref,
#     123         raw_results=self.raw_results,
#     124         exclusive=self.exclusive)
#     125     sen_score[m] = {s: sc[s] for s in self.stats}
#     127 if self.return_lengths:
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/rouge/rouge.py:53, in Rouge.<lambda>(hyp, ref, **k)
#      50 class Rouge:
#      51     DEFAULT_METRICS = ["rouge-1", "rouge-2", "rouge-l"]
#      52     AVAILABLE_METRICS = {
# ---> 53         "rouge-1": lambda hyp, ref, **k: rouge_score.rouge_n(hyp, ref, 1, **k),
#      54         "rouge-2": lambda hyp, ref, **k: rouge_score.rouge_n(hyp, ref, 2, **k),
#      55         "rouge-3": lambda hyp, ref, **k: rouge_score.rouge_n(hyp, ref, 3, **k),
#      56         "rouge-4": lambda hyp, ref, **k: rouge_score.rouge_n(hyp, ref, 4, **k),
#      57         "rouge-5": lambda hyp, ref, **k: rouge_score.rouge_n(hyp, ref, 5, **k),
#      58         "rouge-l": lambda hyp, ref, **k:
#      59             rouge_score.rouge_l_summary_level(hyp, ref, **k),
#      60     }
#      61     DEFAULT_STATS = ["r", "p", "f"]
#      62     AVAILABLE_STATS = ["r", "p", "f"]
#
# File ~/mambaforge/envs/ai/lib/python3.10/site-packages/rouge/rouge_score.py:253, in rouge_n(evaluated_sentences, reference_sentences, n, raw_results, exclusive)
#     235 """
#     236 Computes ROUGE-N of two text collections of sentences.
#     237 Sourece: http://research.microsoft.com/en-us/um/people/cyl/download/
#    (...)
#     250   ValueError: raises exception if a param has len <= 0
#     251 """
#     252 if len(evaluated_sentences) <= 0:
# --> 253     raise ValueError("Hypothesis is empty.")
#     254 if len(reference_sentences) <= 0:
#     255     raise ValueError("Reference is empty.")
#
# ValueError: Hypothesis is empty.

# %%
total_rows = len(df)
total_rouge_1_f1 = 0
total_rouge_2_f1 = 0
total_rouge_l_f1 = 0
total_rouge_1_precision = 0
total_rouge_2_precision = 0
total_rouge_l_precision = 0
total_rouge_1_recall = 0
total_rouge_2_recall = 0
total_rouge_l_recall = 0

for row in df['ROUGE Scores']:
    total_rouge_1_f1 += row['rouge-1']['f']
    total_rouge_2_f1 += row['rouge-2']['f']
    total_rouge_l_f1 += row['rouge-l']['f']
    total_rouge_1_precision += row['rouge-1']['p']
    total_rouge_2_precision += row['rouge-2']['p']
    total_rouge_l_precision += row['rouge-l']['p']
    total_rouge_1_recall += row['rouge-1']['r']
    total_rouge_2_recall += row['rouge-2']['r']
    total_rouge_l_recall += row['rouge-l']['r']

average_rouge_1_f1 = total_rouge_1_f1 / total_rows
average_rouge_2_f1 = total_rouge_2_f1 / total_rows
average_rouge_l_f1 = total_rouge_l_f1 / total_rows
average_rouge_1_precision = total_rouge_1_precision / total_rows
average_rouge_2_precision = total_rouge_2_precision / total_rows
average_rouge_l_precision = total_rouge_l_precision / total_rows
average_rouge_1_recall = total_rouge_1_recall / total_rows
average_rouge_2_recall = total_rouge_2_recall / total_rows
average_rouge_l_recall = total_rouge_l_recall / total_rows

print("Average ROUGE-1 F1 Score:", average_rouge_1_f1)
print("Average ROUGE-2 F1 Score:", average_rouge_2_f1)
print("Average ROUGE-L F1 Score:", average_rouge_l_f1)
print("Average ROUGE-1 Precision:", average_rouge_1_precision)
print("Average ROUGE-2 Precision:", average_rouge_2_precision)
print("Average ROUGE-L Precision:", average_rouge_l_precision)
print("Average ROUGE-1 Recall:", average_rouge_1_recall)
print("Average ROUGE-2 Recall:", average_rouge_2_recall)
print("Average ROUGE-L Recall:", average_rouge_l_recall)
# Out:
# Average ROUGE-1 F1 Score: 0.48751423067966293
# Average ROUGE-2 F1 Score: 0.3079589279053287
# Average ROUGE-L F1 Score: 0.4460853282167372
# Average ROUGE-1 Precision: 0.5169525186815209
# Average ROUGE-2 Precision: 0.33129341283685604
# Average ROUGE-L Precision: 0.4734314449052739
# Average ROUGE-1 Recall: 0.5095914468356101
# Average ROUGE-2 Recall: 0.3319517731626096
# Average ROUGE-L Recall: 0.46622241564332095
